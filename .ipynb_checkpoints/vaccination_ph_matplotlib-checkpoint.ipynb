# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
dfFilter = df[df.country == 'Philippines']
dfFilter[['date', 'total_vaccinations']].plot()
plt.show()

# %%
dfFilter[['date', 'daily_vaccinations']].plot()
plt.show()
